# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# A model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_33/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 6s 23ms/step - loss: 0.4828 - binary_accuracy: 0.7708 - val_loss: 0.4305 - val_binary_accuracy: 0.7949
# Epoch 2/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.4246 - binary_accuracy: 0.7997 - val_loss: 0.4024 - val_binary_accuracy: 0.8132
# Epoch 3/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.4103 - binary_accuracy: 0.8078 - val_loss: 0.3938 - val_binary_accuracy: 0.8195
# Epoch 4/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.4031 - binary_accuracy: 0.8116 - val_loss: 0.3877 - val_binary_accuracy: 0.8229
# Epoch 5/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3978 - binary_accuracy: 0.8147 - val_loss: 0.3872 - val_binary_accuracy: 0.8240
# Epoch 6/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3918 - binary_accuracy: 0.8172 - val_loss: 0.3858 - val_binary_accuracy: 0.8230
# Epoch 7/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3883 - binary_accuracy: 0.8204 - val_loss: 0.3789 - val_binary_accuracy: 0.8283
# Epoch 8/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3851 - binary_accuracy: 0.8205 - val_loss: 0.3749 - val_binary_accuracy: 0.8291
# Epoch 9/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3810 - binary_accuracy: 0.8232 - val_loss: 0.3714 - val_binary_accuracy: 0.8321
# Epoch 10/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3788 - binary_accuracy: 0.8252 - val_loss: 0.3705 - val_binary_accuracy: 0.8304
# Epoch 11/200
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3771 - binary_accuracy: 0.8252 - val_loss: 0.3674 - val_binary_accuracy: 0.8324
# Epoch 12/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3734 - binary_accuracy: 0.8272 - val_loss: 0.3695 - val_binary_accuracy: 0.8313
# Epoch 13/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3716 - binary_accuracy: 0.8276 - val_loss: 0.3645 - val_binary_accuracy: 0.8340
# Epoch 14/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3692 - binary_accuracy: 0.8295 - val_loss: 0.3621 - val_binary_accuracy: 0.8352
# Epoch 15/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3669 - binary_accuracy: 0.8307 - val_loss: 0.3628 - val_binary_accuracy: 0.8356
# Epoch 16/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3658 - binary_accuracy: 0.8306 - val_loss: 0.3632 - val_binary_accuracy: 0.8338
# Epoch 17/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3646 - binary_accuracy: 0.8315 - val_loss: 0.3625 - val_binary_accuracy: 0.8344
# Epoch 18/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3632 - binary_accuracy: 0.8313 - val_loss: 0.3578 - val_binary_accuracy: 0.8360
# Epoch 19/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3606 - binary_accuracy: 0.8335 - val_loss: 0.3606 - val_binary_accuracy: 0.8359
# Epoch 20/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3590 - binary_accuracy: 0.8340 - val_loss: 0.3595 - val_binary_accuracy: 0.8381
# Epoch 21/200
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3575 - binary_accuracy: 0.8338 - val_loss: 0.3567 - val_binary_accuracy: 0.8361
# Epoch 22/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3557 - binary_accuracy: 0.8353 - val_loss: 0.3565 - val_binary_accuracy: 0.8356
# Epoch 23/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3556 - binary_accuracy: 0.8361 - val_loss: 0.3572 - val_binary_accuracy: 0.8356
# Epoch 24/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3541 - binary_accuracy: 0.8376 - val_loss: 0.3542 - val_binary_accuracy: 0.8383
# Epoch 25/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3529 - binary_accuracy: 0.8375 - val_loss: 0.3545 - val_binary_accuracy: 0.8371
# Epoch 26/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3517 - binary_accuracy: 0.8382 - val_loss: 0.3545 - val_binary_accuracy: 0.8376
# Epoch 27/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3514 - binary_accuracy: 0.8386 - val_loss: 0.3560 - val_binary_accuracy: 0.8371
# Epoch 28/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3500 - binary_accuracy: 0.8389 - val_loss: 0.3526 - val_binary_accuracy: 0.8389
# Epoch 29/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3495 - binary_accuracy: 0.8388 - val_loss: 0.3507 - val_binary_accuracy: 0.8410
# Epoch 30/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3485 - binary_accuracy: 0.8393 - val_loss: 0.3526 - val_binary_accuracy: 0.8394
# Epoch 31/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3480 - binary_accuracy: 0.8400 - val_loss: 0.3509 - val_binary_accuracy: 0.8400
# Epoch 32/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3459 - binary_accuracy: 0.8405 - val_loss: 0.3536 - val_binary_accuracy: 0.8375
# Epoch 33/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3448 - binary_accuracy: 0.8407 - val_loss: 0.3513 - val_binary_accuracy: 0.8390
# Epoch 34/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3447 - binary_accuracy: 0.8408 - val_loss: 0.3500 - val_binary_accuracy: 0.8402
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
